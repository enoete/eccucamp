# %%
# Assistant
# Import the required libraries
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# Create a new canvas for shapes demo
shapes_canvas = Image.new('RGB', (600, 400), 'lightblue')
shapes_draw = ImageDraw.Draw(shapes_canvas)

# 1. RECTANGLES - defined by two corners
print("🔲 Drawing rectangles...")
shapes_draw.rectangle([50, 50, 150, 100], fill='red', outline='black', width=2)
shapes_draw.rectangle([200, 50, 300, 100], fill='green')

# 2. CIRCLES/ELLIPSES - defined by bounding box
print("🔵 Drawing circles...")
shapes_draw.ellipse([350, 50, 450, 150], fill='blue', outline='navy', width=3)
shapes_draw.ellipse([500, 50, 550, 100], fill='yellow')  # Oval

# 3. LINES - defined by start and end points
print("📏 Drawing lines...")
shapes_draw.line([(50, 200), (150, 250)], fill='purple', width=5)
shapes_draw.line([(200, 200), (300, 200), (250, 250), (200, 200)], fill='orange', width=3)  # Connected lines

# 4. POLYGONS - defined by list of points
print("🔺 Drawing polygons...")
triangle_points = [(400, 200), (450, 150), (500, 200)]
shapes_draw.polygon(triangle_points, fill='pink', outline='red', width=2)

# Star shape
star_points = [(350, 300), (365, 270), (380, 300), (360, 285), (370, 315)]
shapes_draw.polygon(star_points, fill='gold', outline='orange', width=2)

# Display shapes demo
plt.figure(figsize=(12, 8))
plt.imshow(shapes_canvas)
plt.title("🎨 Basic Shapes Toolkit")
plt.axis('off')
plt.show()

print("✅ Basic shapes mastered!")
print("💡 Key concept: All shapes are defined by coordinates (x, y)")
print("   • (0, 0) is top-left corner")
print("   • x increases going right")
print("   • y increases going down")
# Out:
# 🔲 Drawing rectangles...
# 🔵 Drawing circles...
# 📏 Drawing lines...
# 🔺 Drawing polygons...
# ✅ Basic shapes mastered!
# 💡 Key concept: All shapes are defined by coordinates (x, y)
#    • (0, 0) is top-left corner
#    • x increases going right
#    • y increases going down

# %%
print("\n📚 LESSON 3: Working with Colors")

# Create color demo canvas
color_canvas = Image.new('RGB', (600, 300), 'white')
color_draw = ImageDraw.Draw(color_canvas)

# Different ways to specify colors
print("🌈 Different ways to specify colors:")

# 1. Color names (simple but limited)
color_draw.rectangle([50, 50, 100, 100], fill='red')
color_draw.text((55, 110), "red", fill='black')

# 2. RGB tuples (precise control)
color_draw.rectangle([120, 50, 170, 100], fill=(255, 128, 0))  # Orange
color_draw.text((125, 110), "RGB", fill='black')

# 3. Hex codes (web colors)
color_draw.rectangle([190, 50, 240, 100], fill='#00FF80')  # Bright green
color_draw.text((195, 110), "Hex", fill='black')

# St. Kitts & Nevis flag colors
print("🇰🇳 St. Kitts & Nevis flag colors:")
FLAG_GREEN = (0, 128, 0)
FLAG_RED = (255, 0, 0)
FLAG_BLACK = (0, 0, 0)
FLAG_YELLOW = (255, 255, 0)
FLAG_WHITE = (255, 255, 255)

# Display flag colors
x_start = 300
for i, (color, name) in enumerate([(FLAG_GREEN, "Green"), (FLAG_RED, "Red"), 
                                  (FLAG_BLACK, "Black"), (FLAG_YELLOW, "Yellow"), 
                                  (FLAG_WHITE, "White")]):
    x = x_start + i * 60
    color_draw.rectangle([x, 50, x+50, 100], fill=color, outline='gray')
    color_draw.text((x+5, 110), name, fill='black')

# Natural St. Kitts colors
print("🌴 Natural St. Kitts colors:")
OCEAN_BLUE = (0, 119, 190)
SUNSET_ORANGE = (255, 94, 77)
PALM_GREEN = (34, 139, 34)
SAND_BEIGE = (245, 245, 220)

# Display natural colors
y_start = 180
for i, (color, name) in enumerate([(OCEAN_BLUE, "Ocean"), (SUNSET_ORANGE, "Sunset"), 
                                  (PALM_GREEN, "Palm"), (SAND_BEIGE, "Sand")]):
    x = 100 + i * 100
    color_draw.rectangle([x, y_start, x+80, y_start+50], fill=color, outline='gray')
    color_draw.text((x+5, y_start+55), name, fill='black')

plt.figure(figsize=(12, 6))
plt.imshow(color_canvas)
plt.title("🎨 St. Kitts & Nevis Color Palette")
plt.axis('off')
plt.show()

print("✅ Color systems mastered!")
# Out:
# 📚 LESSON 3: Working with Colors
# 🌈 Different ways to specify colors:
# 🇰🇳 St. Kitts & Nevis flag colors:
# 🌴 Natural St. Kitts colors:
# ✅ Color systems mastered!

# %% [markdown]
# # ============================================================================
# # MARKDOWN CELL: St. Kitts & Nevis Flag Debug Challenge
# # ============================================================================
# """
# ## 🇰🇳 St. Kitts & Nevis Flag Debug Challenge
#
# **Your Mission:** The code below ATTEMPTS to recreate the St. Kitts & Nevis flag, but it has several bugs!
# Your job is to find and fix the mistakes to make it look like the real flag.
#
# ### 🎯 Real Flag Requirements:
# - **Green triangles**: Upper left and lower right
# - **Red triangles**: Upper right and lower left
# - **Black diagonal band**: Running from lower-left to upper-right
# - **Yellow stripes**: Bordering the black band
# - **Two white stars**: Positioned on the black diagonal band
#
# ### 🐛 Debug Challenge:
# The code below has **6-8 intentional bugs**. Can you spot and fix them?
#
# **Bug Categories to Look For:**
# - Triangle positioning errors 📐
# - Diagonal calculation mistakes 🧮
# - Color/drawing order issues 🎨
# - Coordinate calculation bugs 📏
# - Star positioning problems ⭐
#
# Good luck debugging! 🕵️‍♀️

# %%
import math
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

print("🇰🇳 DEBUG CHALLENGE: ST. KITTS & NEVIS FLAG")
print("This code has bugs! Can you find and fix them?")

# Flag dimensions (maintaining proper proportions)
flag_width = 600
flag_height = 400

# Official flag colors
FLAG_GREEN = (0, 128, 0)
FLAG_RED = (255, 0, 0) 
FLAG_BLACK = (0, 0, 0)
FLAG_YELLOW = (255, 255, 0)
FLAG_WHITE = (255, 255, 255)

# Create flag canvas
flag = Image.new('RGB', (flag_width, flag_height), FLAG_WHITE)
flag_draw = ImageDraw.Draw(flag)

print("Step 1: Drawing the triangular backgrounds...")

# BUG 1: Triangle coordinates are wrong! 
# These triangles don't properly fill the flag areas
green_triangle_1 = [(0, 0), (flag_width//3, 0), (0, flag_height//2)]  # Should go to center, not 1/3!
flag_draw.polygon(green_triangle_1, fill=FLAG_GREEN)

# BUG 2: This triangle is completely wrong!
green_triangle_2 = [(flag_width, flag_height), (flag_width//3, flag_height), (flag_width, flag_height//2)]  
flag_draw.polygon(green_triangle_2, fill=FLAG_GREEN)

# BUG 3: Red triangles also have wrong coordinates
red_triangle_1 = [(flag_width, 0), (flag_width//3, 0), (flag_width, flag_height//2)]
flag_draw.polygon(red_triangle_1, fill=FLAG_RED)

# BUG 4: This triangle doesn't connect properly
red_triangle_2 = [(0, flag_height), (flag_width//3, flag_height), (0, flag_height//2)]
flag_draw.polygon(red_triangle_2, fill=FLAG_RED)

print("Step 2: Adding the diagonal black band...")

# BUG 5: Band is way too thick!
band_width = 200  # This is huge! Should be much smaller
offset = band_width // 2

# BUG 6: Diagonal going wrong direction! Should be lower-left to upper-right
black_band = [
    (0, 0 + offset),              # Wrong! Going from upper-left 
    (0, 0 - offset), 
    (flag_width, flag_height - offset),  # to lower-right
    (flag_width, flag_height + offset)
]
flag_draw.polygon(black_band, fill=FLAG_BLACK)

print("Step 3: Adding yellow border stripes...")

# BUG 7: Stripes are too thick and positioned wrong
stripe_width = 50  # Way too thick!

# These stripe calculations are wrong because the black band direction is wrong
upper_stripe = [
    (0, 0 + offset + stripe_width),
    (0, 0 + offset),
    (flag_width, flag_height - offset),
    (flag_width, flag_height - offset - stripe_width)
]
flag_draw.polygon(upper_stripe, fill=FLAG_YELLOW)

lower_stripe = [
    (0, 0 - offset),
    (0, 0 - offset - stripe_width),  # BUG 8: Negative coordinates!
    (flag_width, flag_height + offset + stripe_width),
    (flag_width, flag_height + offset)
]
flag_draw.polygon(lower_stripe, fill=FLAG_YELLOW)

print("Step 4: Adding the two white stars...")

# Star drawing function (this part is correct)
def draw_star(draw, center_x, center_y, size, color):
    """Draw a 5-pointed star"""
    points = []
    for i in range(10):  # 10 points for a star (5 outer, 5 inner)
        angle = math.pi * i / 5
        if i % 2 == 0:  # Outer points
            radius = size
        else:  # Inner points
            radius = size * 0.4
        x = center_x + radius * math.cos(angle - math.pi/2)
        y = center_y + radius * math.sin(angle - math.pi/2)
        points.append((x, y))
    draw.polygon(points, fill=color)

# BUG 9: Star positions are wrong because they're calculated for the wrong diagonal!
star1_x, star1_y = flag_width * 0.3, flag_height * 0.3  # Should be on the diagonal line
star2_x, star2_y = flag_width * 0.7, flag_height * 0.7  # These positions are random!

draw_star(flag_draw, star1_x, star1_y, 20, FLAG_WHITE)
draw_star(flag_draw, star2_x, star2_y, 20, FLAG_WHITE)

print("✅ Flag complete... or is it? 🤔")

# Display the buggy flag
plt.figure(figsize=(12, 8))
plt.imshow(flag)
plt.title("🇰🇳 St. Kitts & Nevis Flag (BUGGY VERSION)")
plt.axis('off')
plt.show()

# Save the buggy flag
flag.save("st_kitts_nevis_flag_buggy.png")
print("💾 Buggy flag saved for comparison")

print("\n🐛 FOUND THE BUGS? Here are some hints...")
# Out:
# 🇰🇳 DEBUG CHALLENGE: ST. KITTS & NEVIS FLAG
# This code has bugs! Can you find and fix them?
# Step 1: Drawing the triangular backgrounds...
# Step 2: Adding the diagonal black band...
# Step 3: Adding yellow border stripes...
# Step 4: Adding the two white stars...
# ✅ Flag complete... or is it? 🤔
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127472 (\N{REGIONAL INDICATOR SYMBOL LETTER K}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127475 (\N{REGIONAL INDICATOR SYMBOL LETTER N}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 💾 Buggy flag saved for comparison
#
# 🐛 FOUND THE BUGS? Here are some hints...

# %% [markdown]
# ## 🔍 St. Kitts & Nevis Flag Debugging Hints
#
# ### 🐛 Bug Hunt Checklist:
#
# #### 📐 Triangle Problems (Bugs 1-4):
# - **Hint 1**: Triangles should meet at the CENTER of the flag, not 1/3 of the way
# - **Hint 2**: Check your triangle coordinates - do they reach all the way to the edges?
# - **Hint 3**: Green triangles should be: upper-left AND lower-right
# - **Hint 4**: Red triangles should be: upper-right AND lower-left
# - **Try**: Change `flag_width//3` to `flag_width//2` and fix the coordinate patterns
#
# #### 🖤 Diagonal Band Problems (Bugs 5-6):
# - **Hint 5**: The band is HUGE! Try `band_width = 80` instead of 200
# - **Hint 6**: Diagonal should go from bottom-left `(0, flag_height)` to top-right `(flag_width, 0)`
# - **Current bug**: It's going from top-left to bottom-right - completely backwards!
# - **Try**: Swap your coordinates to fix the diagonal direction
#
# #### 💛 Yellow Stripe Problems (Bugs 7-8):
# - **Hint 7**: Stripes are too thick! Try `stripe_width = 15` instead of 50
# - **Hint 8**: Negative coordinates `(0, -offset)` go off the canvas!
# - **Hint 9**: If you fix the diagonal direction, the stripe coordinates will need to match
# - **Try**: Follow the same diagonal pattern as the corrected black band
#
# #### ⭐ Star Position Problems (Bug 9):
# - **Hint 10**: Stars should sit ON the diagonal black band, not floating randomly
# - **Hint 11**: If diagonal goes from `(0, height)` to `(width, 0)`, calculate points along that line
# - **Try**: For a point 30% along the diagonal: `x = 0.3 * width`, `y = height - (0.3 * height)`
#
# ### 🔧 Debugging Strategy:
# 1. **Fix triangles first** - comment out band/stripes/stars and get triangles right
# 2. **Fix diagonal direction** - get the black band going the right way
# 3. **Adjust band thickness** - make it look proportional
# 4. **Fix yellow stripes** - make them follow the corrected diagonal
# 5. **Position stars correctly** - calculate along the diagonal line
#
# ### ✅ Success Check:
# Your flag is correct when:
# - [ ] **Four colored triangles** meet at the center and fill the entire flag
# - [ ] **No white background** shows except for stars
# - [ ] **Diagonal runs** from bottom-left to top-right
# - [ ] **Black band** is reasonably thick (not huge, not tiny)
# - [ ] **Yellow stripes** border the black band properly
# - [ ] **Two stars** sit on the black diagonal band
#
# ### 💡 Pro Tips:
# - **Print coordinates** to debug: `print(f"Triangle points: {green_triangle_1}")`
# - **Test one element** at a time by commenting out others
# - **Look at the real flag** online for reference
# - **Don't worry** if it takes several attempts - debugging is a skill!
#
# **Remember**: Every bug you find makes you a stronger programmer! 🕵️‍♀️💪
# """

# %% [markdown]
# **Your Mission:** The code below ATTEMPTS to create the Antigua & Barbuda flag, but it has several bugs!
# Your job is to find and fix the mistakes.
#
# ### 🎯 Antigua & Barbuda Flag Design:
# - **Top section**: Red triangle
# - **Middle section**: Black horizontal band
# - **Bottom section**: Blue triangle
# - **Center**: Yellow/gold sun with rays (rising sun symbol)
# - **Colors**: Red represents energy, Black represents African heritage, Blue represents the Caribbean Sea
#
# ### 🐛 Debug Challenge:
# The code below has **5-7 intentional mistakes**. Can you spot them and fix them?
#
# **Hint Categories:**
# - Color mistakes 🎨
# - Shape positioning errors 📐
# - Size/proportion issues 📏
# - Drawing order problems 🔄
# - Coordinate calculation bugs 🧮
#
# Good luck debugging! Remember: real programmers spend more time debugging than writing new code! 🔍

# %%
print("🇦🇬 DEBUGGING CHALLENGE: ANTIGUA & BARBUDA FLAG")
print("This code has bugs! Can you find and fix them?")

# Import required libraries
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import math

# Flag dimensions
flag_width = 600
flag_height = 400

# Antigua & Barbuda flag colors
FLAG_RED = (255, 0, 0)
FLAG_BLACK = (0, 0, 0)
FLAG_BLUE = (0, 0, 255)        # BUG 1: This should be a lighter Caribbean blue!
FLAG_YELLOW = (255, 255, 0)   # Sun color
FLAG_WHITE = (255, 255, 255)

print("Creating Antigua & Barbuda flag...")

# Create flag canvas
antigua_flag = Image.new('RGB', (flag_width, flag_height), FLAG_WHITE)
antigua_draw = ImageDraw.Draw(antigua_flag)

print("Step 1: Drawing the base triangular sections...")

# Top red triangle (should cover top half)
red_triangle = [
    (0, 0),                    # Top left
    (flag_width, 0),           # Top right  
    (flag_width//2, flag_height//3)  # BUG 2: This point is wrong! Should go to middle of flag
]
antigua_draw.polygon(red_triangle, fill=FLAG_RED)

# Bottom blue triangle (should cover bottom half)
blue_triangle = [
    (0, flag_height),          # Bottom left
    (flag_width, flag_height), # Bottom right
    (flag_width//2, flag_height//2)  # Center point
]
antigua_draw.polygon(blue_triangle, fill=FLAG_BLUE)

print("Step 2: Drawing the black horizontal band...")

# Black horizontal band in the middle
band_height = flag_height // 6  # BUG 3: This band is too thin! Should be thicker
band_top = (flag_height - band_height) // 2
band_bottom = band_top + band_height

# BUG 4: The black band should extend full width, but this doesn't cover the triangular areas properly
antigua_draw.rectangle([0, band_top, flag_width, band_bottom], fill=FLAG_BLACK)

print("Step 3: Drawing the rising sun...")

# Sun position (should be in center of flag)
sun_x = flag_width // 2
sun_y = flag_height // 2

# BUG 5: Sun is too small! Should be more prominent
sun_radius = 25  

# Draw sun circle
antigua_draw.ellipse([
    sun_x - sun_radius, 
    sun_y - sun_radius,
    sun_x + sun_radius, 
    sun_y + sun_radius
], fill=FLAG_YELLOW, outline=FLAG_BLACK, width=2)

print("Step 4: Drawing sun rays...")

# BUG 6: Only drawing 4 rays, but should have many more rays for a proper sun!
num_rays = 4
ray_length = 40

for i in range(num_rays):
    angle = (360 / num_rays) * i
    # Convert to radians
    angle_rad = math.radians(angle)
    
    # Calculate ray end point
    end_x = sun_x + ray_length * math.cos(angle_rad)
    end_y = sun_y + ray_length * math.sin(angle_rad)  # BUG 7: Should use different calculation for rising sun
    
    # Draw ray
    antigua_draw.line([(sun_x, sun_y), (end_x, end_y)], fill=FLAG_YELLOW, width=3)

print("✅ Antigua & Barbuda flag complete... or is it? 🤔")

# Display the buggy flag
plt.figure(figsize=(12, 8))
plt.imshow(antigua_flag)
plt.title("🇦🇬 Antigua & Barbuda Flag (Buggy Version)")
plt.axis('off')
plt.show()

# Save the buggy flag for comparison
antigua_flag.save("antigua_barbuda_flag_buggy.png")
print("💾 Buggy flag saved as 'antigua_barbuda_flag_buggy.png'")

print("\n🐛 DEBUG CHALLENGE:")
print("Can you spot the bugs and fix them?")
print("Hint: Look carefully at colors, shapes, proportions, and completeness!")
# Out:
# 🇦🇬 DEBUGGING CHALLENGE: ANTIGUA & BARBUDA FLAG
# This code has bugs! Can you find and fix them?
# Creating Antigua & Barbuda flag...
# Step 1: Drawing the base triangular sections...
# Step 2: Drawing the black horizontal band...
# Step 3: Drawing the rising sun...
# Step 4: Drawing sun rays...
# ✅ Antigua & Barbuda flag complete... or is it? 🤔
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127462 (\N{REGIONAL INDICATOR SYMBOL LETTER A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/anaconda-ai-2024.04-py310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127468 (\N{REGIONAL INDICATOR SYMBOL LETTER G}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 💾 Buggy flag saved as 'antigua_barbuda_flag_buggy.png'
#
# 🐛 DEBUG CHALLENGE:
# Can you spot the bugs and fix them?
# ...

# %% [markdown]
# ## 🔍 Debugging Hints - Antigua & Barbuda Flag
#
# If you're having trouble finding the bugs, here are some hints:
#
# ### 🎨 Color Issues:
# - **Hint 1**: Check if the blue matches Caribbean waters
# - **Research**: Look up the official Antigua & Barbuda flag colors
# - **Try**: A lighter, more tropical blue like `(0, 114, 178)` or `(52, 152, 219)`
#
# ### 📐 Shape & Proportion Problems:
# - **Hint 2**: Where should the triangles meet? Top and bottom halves?
# - **Hint 3**: How thick should the black band be? Too thin? Too thick?
# - **Try**: The band should be prominent but not overwhelming
#
# ### ☀️ Sun Symbol Issues:
# - **Hint 4**: Is the sun big enough to be the focal point?
# - **Hint 5**: How many rays should a sun have? 4 seems too few...
# - **Hint 6**: Should all rays point outward equally, or is this a "rising" sun?
#
# ### 🔄 Drawing Order Problems:
# - **Hint 7**: What gets drawn on top of what? Should the sun be visible through the band?
#
# ### 🧮 Mathematical Bugs:
# - **Hint 8**: Check your coordinate calculations - are triangles meeting properly?
# - **Hint 9**: Are ray calculations correct for a sun symbol?
#
# ### 🔧 Debugging Strategy:
# 1. **Compare with reference**: Look up the real Antigua & Barbuda flag
# 2. **Test one element**: Comment out parts to isolate issues
# 3. **Check proportions**: Does each section take the right amount of space?
# 4. **Color accuracy**: Do the colors match the official design?
# 5. **Symbol completeness**: Does the sun look like a proper rising sun?
#
# ### ✅ Success Criteria:
# Your flag is correct when:
# - [ ] **Colors match** the official Antigua & Barbuda flag
# - [ ] **Triangles properly divide** the flag into top and bottom halves
# - [ ] **Black band** is the right thickness and prominence
# - [ ] **Sun symbol** is appropriately sized and detailed
# - [ ] **Sun rays** represent a proper rising sun
# - [ ] **Overall proportions** look balanced and official
#
# **Remember**: Debugging is a skill! Each bug you find makes you a better programmer! 🕵️‍♀️✨

# %% [markdown]
# ## 🎓 Debugging Skills Reflection
#
# ### 🧠 What You're Learning:
# Debugging is one of the most important programming skills! By working through this challenge, you're developing:
#
# - **Problem-solving mindset**: Breaking complex issues into smaller parts
# - **Attention to detail**: Spotting subtle mistakes in code
# - **Research skills**: Comparing your output with reference images
# - **Persistence**: Not giving up when code doesn't work perfectly
# - **Testing strategies**: Isolating problems and testing fixes
#
# ### 🌟 Real-World Connection:
# Professional programmers spend 50-70% of their time debugging! This isn't just a classroom exercise - it's exactly what software developers do every day. Companies value programmers who can:
#
# - Find bugs quickly and efficiently
# - Test their fixes thoroughly
# - Learn from their mistakes
# - Help others debug their code
# - Stay calm under pressure when things break
#
# ### 🎯 Why Caribbean Flags Matter:
# Each flag represents:
# - **Cultural identity** and national pride
# - **Historical significance** and independence
# - **Artistic design** principles and symbolism
# - **Technical precision** in recreation
# - **Regional unity** among Caribbean nations
#
# By accurately recreating these flags with code, you're preserving and celebrating Caribbean heritage through technology!
#
# ### 🚀 Next Steps:
# Once you've mastered debugging the Antigua & Barbuda flag, try:
# - Creating flags for other Caribbean nations
# - Adding animations (waving effects)
# - Building a complete Caribbean flag collection
# - Teaching others your debugging strategies
#
# **Remember**: Every bug you fix makes you a stronger programmer! 💪🐛➡️✨

# %% [markdown]
# ## 🎓 Debugging Skills Gained
#
# ### 🧠 What You're Learning:
# By working through this flag debugging challenge, you're developing crucial programming skills:
#
# - **Problem Decomposition**: Breaking a complex visual problem into smaller parts
# - **Coordinate Geometry**: Understanding how mathematical coordinates create visual shapes
# - **Systematic Testing**: Isolating problems and testing fixes incrementally
# - **Visual Debugging**: Comparing your output with a reference to spot differences
# - **Attention to Detail**: Noticing subtle positioning and calculation errors
# - **Persistence**: Not giving up when code doesn't work perfectly on the first try
#
# ### 🌟 Real-World Application:
# These debugging skills transfer directly to professional programming:
# - **Web Development**: Fixing layout and positioning bugs
# - **Game Development**: Correcting sprite positioning and collision detection
# - **Data Visualization**: Ensuring charts and graphs display correctly
# - **Mobile Apps**: Resolving UI element placement issues
# - **Scientific Computing**: Debugging mathematical algorithms and calculations
#
# ### 🏛️ Cultural Coding Connection:
# By accurately recreating the St. Kitts & Nevis flag, you're:
# - **Preserving Heritage**: Using technology to maintain cultural symbols
# - **Developing Precision**: Learning that cultural representation requires accuracy
# - **Building Respect**: Understanding that details matter in cultural work
# - **Creating Tools**: Building skills to digitally preserve any cultural artifact
#
# **Remember**: Every professional programmer spends significant time debugging.
# This isn't just a classroom exercise - it's exactly what software developers do every day! 💻✨
